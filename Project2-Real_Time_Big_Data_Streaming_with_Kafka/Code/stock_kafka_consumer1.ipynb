# %% [markdown]
# <a href="https://colab.research.google.com/github/safarie1103/dsc650/blob/master/ExternalResources/Real_Time_Big_Data_Streaming_Spark_Kafka-main/flight_kafka_consumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=blue> Real Time Stock Ticker Streaming - Kafka Consumer </font>

# %%
# !pip install kafka-python

# %% [markdown]
# Consuming data the data being streamed using Kafka and plotting it.

# %%
# import statements
import pandas as pd
from time import sleep
from kafka import KafkaConsumer
import datetime as dt
import matplotlib
import numpy as np
import copy
import matplotlib.pyplot as plt
from json import loads

# %% [markdown]
# ## Step 1
#
# #### Set topic, connect consumer to producer and set plotting function

# %%
# set the topic of the consumer
topic = 'stock_ticker'

# function to connect to kafka consumer
# taken from tutorial week 9
def connect_kafka_consumer():
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   consumer_timeout_ms=240000, # stop iteration if no message after 10 sec
                                   auto_offset_reset='latest', # comment this if you don't want to consume earliest available message
                                   bootstrap_servers=['192.168.86.48:9092'],
                                   value_deserializer=lambda x: loads(x.decode('ascii')),
                                   api_version=(0, 11,5))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer

    
# function to set up the plotting area
# taken from tutorial week 9
def init_plots():
    try:
        
        width = 25
        height = 20
        fig = plt.figure(figsize=(width,height)) # create new figure
        ax = fig.add_subplot(111) # adding the subplot axes to the given grid position
        #fig.suptitle('Technical Indicators') # giving figure a title
        #ax.set_xlabel('Date')
        #ax.set_ylabel('countFlightRecords')        
        #fig.show() # displaying the figure
        #fig.canvas.draw() # drawing on the canvas
        return fig, ax
    except Exception as ex:
        print(str(ex))

# %%
def GetStockData(consumer):
    for message in consumer: 
        data = []
        df = pd.DataFrame.from_dict(message.value)
        data.append(df)

# %%
def bbands(price, length=30, numsd=3):    
    ave = price.rolling(window = length, center = False).mean()    
    sd = price.rolling(window = length, center = False).std()
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

# %%
# %matplotlib notebook
plt.style.use('fivethirtyeight')


def GetMessage(consumer,fig, ax):
    try:
        
        for message in consumer: 
                data = []
                #print("New Data...........")
                for stock in range(len(message.value)):            
                    df = pd.DataFrame.from_dict(message.value[stock])               
                    df['Date'] = pd.to_datetime(df['Date'])
                    df = df.reset_index()
                    df = df.set_index('Date')     
                    data.append(df)

                TechIndicator = copy.deepcopy(data)

                #print(TechIndicator[0].index)
                #print(len(TechIndicator))
                


                #"""
                
                for stock in range(len(TechIndicator)):
                    TechIndicator[stock]['BB_Middle_Band'], TechIndicator[stock]['BB_Upper_Band'], TechIndicator[stock]['BB_Lower_Band'] = bbands(TechIndicator[stock]['Close'], length=30, numsd=3)
                    TechIndicator[stock]['BB_Middle_Band'] = TechIndicator[stock]['BB_Middle_Band']
                    TechIndicator[stock]['BB_Upper_Band'] = TechIndicator[stock]['BB_Upper_Band']
                    TechIndicator[stock]['BB_Lower_Band'] = TechIndicator[stock]['BB_Lower_Band']
                    TechIndicator[stock] = TechIndicator[stock].dropna()
                
                for stock in range(len(TechIndicator)):
                    
                    
                    ax = plt.subplot(4,2,stock+1)
                    ax.clear()
                    ax.fill_between(TechIndicator[stock].index, TechIndicator[stock]['BB_Upper_Band'], TechIndicator[stock]['BB_Lower_Band'], color='grey', label="Band Range")
                    # Plot Adjust Closing Price and Moving Averages
                    ax.plot(TechIndicator[stock].index, TechIndicator[stock]['Close'], color='red', lw=2, label="Close")
                    ax.plot(TechIndicator[stock].index, TechIndicator[stock]['BB_Middle_Band'], color='black', lw=2, label="Middle Band")
                    ax.set_title("Bollinger Bands for " + str(TechIndicator[stock]['Label'][0]))
                    ax.legend()
                    ax.set_xlabel("Date")
                    ax.set_ylabel("Value")
                    plt.xticks(rotation=30)
                
                fig.tight_layout()
                
                fig.canvas.draw()
                
        plt.close('all')
                #"""  
    except Exception as ex:
        print(str(ex))

# %%
if __name__ == '__main__':
    
    # call all required functions 
    consumer = connect_kafka_consumer()
    fig, ax = init_plots()  
    GetMessage(consumer,fig, ax)
# Out:
# <img src="data:image/png;base64,..." width="2499.9999458139605">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#       4 consumer = connect_kafka_consumer()
#       5 fig, ax = init_plots()
# ----> 6 GetMessage(consumer,fig, ax)
#
# Input In [6], in GetMessage(consumer, fig, ax)
#       5 def GetMessage(consumer,fig, ax):
#       6     try:
# ----> 8         for message in consumer:
#       9                 data = []
#      10                 #print("New Data...........")
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File c:\users\safar\appdata\local\programs\python\python38-64\lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
