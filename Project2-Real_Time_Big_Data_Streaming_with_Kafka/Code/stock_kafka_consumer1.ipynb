# %% [markdown]
# <a href="https://colab.research.google.com/github/safarie1103/dsc650/blob/master/ExternalResources/Real_Time_Big_Data_Streaming_Spark_Kafka-main/flight_kafka_consumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=blue> Real Time Stock Ticker Streaming - Kafka Consumer </font>

# %%
# !pip install kafka-python

# %% [markdown]
# Consuming data the data being streamed using Kafka and plotting it.

# %%
# import statements
import pandas as pd
from time import sleep
from kafka import KafkaConsumer
import datetime as dt
import matplotlib
import numpy as np
import copy
import matplotlib.pyplot as plt
from json import loads

# %% [markdown]
# ## Step 1
#
# #### Set topic, connect consumer to producer and set plotting function

# %%
# set the topic of the consumer
topic = 'stock_ticker'

# function to connect to kafka consumer
# taken from tutorial week 9
def connect_kafka_consumer():
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   consumer_timeout_ms=240000, # stop iteration if no message after 10 sec
                                   auto_offset_reset='latest', # comment this if you don't want to consume earliest available message
                                   bootstrap_servers=['192.168.86.48:9092'],
                                   value_deserializer=lambda x: loads(x.decode('ascii')),
                                   api_version=(0, 11,5))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer

    
# function to set up the plotting area
# taken from tutorial week 9
def init_plots():
    try:
        
        width = 15
        height = 20
        fig = plt.figure(figsize=(width,height)) # create new figure
        ax = fig.add_subplot(111) # adding the subplot axes to the given grid position
        #fig.suptitle('Technical Indicators') # giving figure a title
        #ax.set_xlabel('Date')
        #ax.set_ylabel('countFlightRecords')        
        #fig.show() # displaying the figure
        #fig.canvas.draw() # drawing on the canvas
        return fig, ax
    except Exception as ex:
        print(str(ex))

# %%
def GetStockData(consumer):
    for message in consumer: 
        data = []
        df = pd.DataFrame.from_dict(message.value)
        data.append(df)

# %%
def bbands(price, length=30, numsd=3):    
    ave = price.rolling(window = length, center = False).mean()    
    sd = price.rolling(window = length, center = False).std()
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

# %%
# %matplotlib notebook
plt.style.use('fivethirtyeight')


def GetMessage(consumer,fig, ax):
    try:
        
        for message in consumer: 
                data = []
                #print("New Data...........")
                for stock in range(len(message.value)):            
                    df = pd.DataFrame.from_dict(message.value[stock])               
                    df['Date'] = pd.to_datetime(df['Date'])
                    df = df.reset_index()
                    df = df.set_index('Date')     
                    data.append(df)

                TechIndicator = copy.deepcopy(data)

                #print(TechIndicator[0].index)
                #print(len(TechIndicator))
                


                #"""
                
                for stock in range(len(TechIndicator)):
                    TechIndicator[stock]['BB_Middle_Band'], TechIndicator[stock]['BB_Upper_Band'], TechIndicator[stock]['BB_Lower_Band'] = bbands(TechIndicator[stock]['Close'], length=30, numsd=3)
                    TechIndicator[stock]['BB_Middle_Band'] = TechIndicator[stock]['BB_Middle_Band']
                    TechIndicator[stock]['BB_Upper_Band'] = TechIndicator[stock]['BB_Upper_Band']
                    TechIndicator[stock]['BB_Lower_Band'] = TechIndicator[stock]['BB_Lower_Band']
                    TechIndicator[stock] = TechIndicator[stock].dropna()
               
                for stock in range(len(TechIndicator)):
                    
                    CurrentValue = TechIndicator[stock]['Close'][len(TechIndicator[stock]['Close'])-1]
                    print('Current Value: ' , CurrentValue)
                    CurrentDate = TechIndicator[stock].index[len(TechIndicator[stock].index)-1]
                    print('CurrentDate: ' , CurrentDate)
                    ax = plt.subplot(4,2,stock+1)
                    ax.clear()
                    ax.fill_between(TechIndicator[stock].index, TechIndicator[stock]['BB_Upper_Band'], TechIndicator[stock]['BB_Lower_Band'], color='grey', label="Band Range")
                    # Plot Adjust Closing Price and Moving Averages
                    ax.plot(TechIndicator[stock].index, TechIndicator[stock]['Close'], color='red', lw=2, label="Close")
                    ax.annotate(str(CurrentValue), (CurrentDate, CurrentValue))
                    ax.plot(TechIndicator[stock].index, TechIndicator[stock]['BB_Middle_Band'], color='black', lw=2, label="Middle Band")
                    ax.set_title("Bollinger Bands for " + str(TechIndicator[stock]['Label'][0]))
                    ax.legend()
                    ax.set_xlabel("Date")
                    ax.set_ylabel("Value")
                    plt.xticks(rotation=30)
                
                fig.tight_layout()
                
                fig.canvas.draw()
                
        plt.close('all')
                #"""  
    except Exception as ex:
        print(str(ex))

# %%
if __name__ == '__main__':
    
    # call all required functions 
    consumer = connect_kafka_consumer()
    fig, ax = init_plots()  
    GetMessage(consumer,fig, ax)
# Out:
# <img src="data:image/png;base64,..." width="1499.9999674883763">
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:07:18.644687
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:07:39.107391
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:07:59.580036
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:10:20.144747
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:10:40.635725
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:11:01.163054
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:13:21.805740
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:13:42.347857
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:14:02.822003
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:16:23.371165
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:16:43.832066
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:17:04.492251
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:19:24.996468
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:19:45.504386
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:20:06.207907
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:22:26.910367
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:22:47.470753
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:23:07.967535
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:25:28.542797
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:25:49.161438
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:26:09.675634
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:28:30.380180
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:28:50.870252
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:29:11.368268
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:31:31.904820
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:31:52.511422
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:32:13.000895
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:34:33.588860
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:34:54.051867
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:35:14.633233
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:37:35.247750
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:37:55.747026
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:38:16.318668
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:40:36.940676
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:40:57.471746
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:41:17.989332
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:43:38.504774
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:43:58.980023
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:44:19.653064
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:46:40.301159
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:47:00.950988
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:47:21.435341
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:49:42.053709
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:50:02.548310
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:50:23.107755
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:52:43.734769
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:53:04.326587
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:53:24.847137
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:55:45.499592
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:56:06.107210
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:56:26.610621
# Current Value:  113.61
# CurrentDate:  2023-04-24 15:58:47.183471
# Current Value:  106.78
# CurrentDate:  2023-04-24 15:59:07.765812
# Current Value:  281.77
# CurrentDate:  2023-04-24 15:59:28.292274
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:01:49.006403
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:02:09.503288
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:02:29.955583
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:04:50.588255
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:05:11.175154
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:05:31.624372
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:07:52.375418
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:08:13.143050
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:08:33.643020
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:10:54.202121
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:11:14.816146
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:11:35.371623
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:13:55.887714
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:14:16.465779
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:14:36.982365
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:16:57.462515
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:17:17.982588
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:17:38.564165
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:19:59.035795
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:20:19.632558
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:20:40.165611
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:23:00.798851
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:23:21.373366
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:23:41.926876
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:26:02.455044
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:26:23.016371
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:26:43.717043
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:29:04.247812
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:29:24.848561
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:29:45.334274
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:32:05.937499
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:32:26.488214
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:32:47.137117
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:35:07.886295
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:35:28.768050
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:35:49.264285
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:38:09.870332
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:38:30.383719
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:38:51.206684
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:41:11.815094
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:41:32.334913
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:41:52.892469
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:44:13.558525
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:44:34.166338
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:44:54.956204
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:47:15.483522
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:47:36.196016
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:47:56.778539
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:50:17.409722
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:50:38.008781
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:50:58.895741
# Current Value:  113.61
# CurrentDate:  2023-04-24 16:53:19.640314
# Current Value:  106.78
# CurrentDate:  2023-04-24 16:53:40.219368
# Current Value:  281.77
# CurrentDate:  2023-04-24 16:54:00.763496
