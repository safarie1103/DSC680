# %% [markdown]
# <a href="https://colab.research.google.com/github/safarie1103/dsc650/blob/master/ExternalResources/Real_Time_Big_Data_Streaming_Spark_Kafka-main/flight_kafka_consumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=blue> Real Time Flight Data Streaming - Kafka Consumer </font>
# **Author:**  Armin Berger

# %%
# !pip install kafka-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kafka-python in /usr/local/lib/python3.8/dist-packages (2.0.2)

# %% [markdown]
# Consuming data the data being streamed using Kafka and plotting it.

# %%
# import statements
from time import sleep
from kafka import KafkaConsumer
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt
from json import loads

# %% [markdown]
# ## Step 1
#
# #### Set topic, connect consumer to producer and set plotting function

# %%
# set the topic of the consumer
topic = 'flightTopic'

# function to connect to kafka consumer
# taken from tutorial week 9
def connect_kafka_consumer():
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   consumer_timeout_ms=10000, # stop iteration if no message after 10 sec
                                   auto_offset_reset='latest', # comment this if you don't want to consume earliest available message
                                   bootstrap_servers=['192.168.86.48:9092'],
                                   value_deserializer=lambda x: loads(x.decode('ascii')),
                                   api_version=(0, 11,5))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer

    
# function to set up the plotting area
# taken from tutorial week 9
def init_plots():
    try:
        width = 9.5
        height = 6
        fig = plt.figure(figsize=(width,height)) # create new figure
        ax = fig.add_subplot(111) # adding the subplot axes to the given grid position
        fig.suptitle('Number of flights every 2 min by keyFlight') # giving figure a title
        ax.set_xlabel('timestamp')
        ax.set_ylabel('countFlightRecords')        
        fig.show() # displaying the figure
        fig.canvas.draw() # drawing on the canvas
        return fig, ax
    except Exception as ex:
        print(str(ex))

# %% [markdown]
# ## Step 2
#
# #### Process the data into the desired batch format and plot it

# %%
# NEW
# this line is needed for the inline display of graphs in Jupyter Notebook
# %matplotlib notebook

    
# function to consume and display the data sent by the prodcuer
# partially taken from tutorial week 9
def countFlightRecords(consumer, fig, ax):
    try:
        
        ## 1. GENERATE THE DATA CONTAINERS
        
        time_start = 0
        
        count_of_flights = {1:0, 2:0, 3:0}
        
        two_min_flight_data = []
        
        data_plot = False 
        
        
        ## 2. PLOTING DATA CONATINERS
        
        # container for x and y values
        y1, y2, y3, x1, x2, x3 = [], [], [], [], [], []
        
        # print the start of the process
        print('Processing records ...')
        
        
        for message in consumer:   

            # in case of the first batch 
            if time_start == 0:
                
                # save the timestamp of a batch
                ts_of_batch = message.value[0]['ts']
                
                # set new ts starting point
                time_start = ts_of_batch
            
            # for any further batches
            else:
                
                # save the timestamp of a batch
                ts_of_batch = message.value[0]['ts']
                
                # if condition when two minutes have passed
                if ts_of_batch - time_start > 120:
                    
                    # set binary switch
                    data_plot = True
                    
                    print('number of flights for keyFlight = ‘1’ : ', count_of_flights[1])
                    print('number of flights for keyFlight = ‘2’ : ', count_of_flights[2])
                    print('number of flights for keyFlight = ‘3’ : ', count_of_flights[3])
                    print('-----------------------')
                    
                    # dict to save the flight countof two minutes
                    two_min_tup = () 
                    
                    # append count for each of the three keyFlights
                    two_min_tup = (ts_of_batch, count_of_flights[1], count_of_flights[2], count_of_flights[3])
                    
                    # append the dict 
                    two_min_flight_data.append(two_min_tup)
                    
                    # append the data for our plotting input
                    x1.append(ts_of_batch)
                    x2.append(ts_of_batch)
                    x3.append(ts_of_batch)
                    y1.append(count_of_flights[1])
                    y2.append(count_of_flights[2])
                    y3.append(count_of_flights[3])
                    
                    # reset the counter for eah keyFlight
                    count_of_flights[1] = 0
                    count_of_flights[2] = 0
                    count_of_flights[3] = 0

                    # set the new 'last' timestamp
                    time_start = ts_of_batch

            
            # save the list of flights received at each iteration
            data_batch_list = message.value
            
            # loop through all the lights in the list 
            for i in range(0,len(data_batch_list)):
                
                # each entry in the list is a dict containing a flight
                flight_dict = data_batch_list[i]
                
                
                if flight_dict['DAY_OF_WEEK'] == '1':
                    
                    count_of_flights[1] += 1
                    
                
                elif flight_dict['DAY_OF_WEEK'] == '2':
                    
                    count_of_flights[2] += 1
                    
                elif flight_dict['DAY_OF_WEEK'] == '3':
                    
                    count_of_flights[3] += 1
                
            
            ## 3. PLOT THE DATA
            
            # start plotting if there are three or more 2 min flight count totals
            # and if variable data_plot is True
            if len(two_min_flight_data) >= 3 and data_plot is True:
                
                
                # visualize and update the graph
                ax.clear()
                ax.plot(x1, y1, label = 'keyFlight = ‘1’')
                ax.plot(x2, y2, label = 'keyFlight = ‘2’')
                ax.plot(x3, y3, label = 'keyFlight = ‘3’')

                ax.set_xlabel('timestamp')
                ax.set_ylabel('countFlightRecords')
                plt.legend()
                fig.canvas.draw()
                
                # set binary switch
                data_plot = False
                
                # removing the item in the first position
                x1.pop(0)
                x2.pop(0)
                x3.pop(0)
                y1.pop(0)
                y2.pop(0)
                y3.pop(0)
            
            
        plt.close('all')
        
    except Exception as ex:
        print(str(ex))
    
if __name__ == '__main__':
    
    # call all required functions 
    consumer = connect_kafka_consumer()
    fig, ax = init_plots()    
    countFlightRecords(consumer, fig, ax)
# Out:
# <img src="data:image/png;base64,..." width="949.999979409305">
# Processing records ...
# number of flights for keyFlight = ‘1’ :  272
# number of flights for keyFlight = ‘2’ :  295
# number of flights for keyFlight = ‘3’ :  258
# -----------------------
# number of flights for keyFlight = ‘1’ :  401
# number of flights for keyFlight = ‘2’ :  346
# number of flights for keyFlight = ‘3’ :  257
# -----------------------
# number of flights for keyFlight = ‘1’ :  275
# number of flights for keyFlight = ‘2’ :  261
# number of flights for keyFlight = ‘3’ :  326
# -----------------------
# number of flights for keyFlight = ‘1’ :  370
# number of flights for keyFlight = ‘2’ :  377
# number of flights for keyFlight = ‘3’ :  350
# -----------------------
# number of flights for keyFlight = ‘1’ :  274
# number of flights for keyFlight = ‘2’ :  268
# number of flights for keyFlight = ‘3’ :  271
# -----------------------
# number of flights for keyFlight = ‘1’ :  390
# number of flights for keyFlight = ‘2’ :  372
# number of flights for keyFlight = ‘3’ :  337
# -----------------------
# number of flights for keyFlight = ‘1’ :  301
# number of flights for keyFlight = ‘2’ :  304
# number of flights for keyFlight = ‘3’ :  290
# -----------------------
# number of flights for keyFlight = ‘1’ :  346
# number of flights for keyFlight = ‘2’ :  386
# number of flights for keyFlight = ‘3’ :  362
# -----------------------
# number of flights for keyFlight = ‘1’ :  279
# number of flights for keyFlight = ‘2’ :  287
# number of flights for keyFlight = ‘3’ :  245
# -----------------------
# number of flights for keyFlight = ‘1’ :  366
# number of flights for keyFlight = ‘2’ :  363
# number of flights for keyFlight = ‘3’ :  328
# -----------------------
# number of flights for keyFlight = ‘1’ :  257
# number of flights for keyFlight = ‘2’ :  254
# number of flights for keyFlight = ‘3’ :  276
# -----------------------
# number of flights for keyFlight = ‘1’ :  365
# number of flights for keyFlight = ‘2’ :  368
# number of flights for keyFlight = ‘3’ :  370
# -----------------------
# number of flights for keyFlight = ‘1’ :  291
# number of flights for keyFlight = ‘2’ :  307
# number of flights for keyFlight = ‘3’ :  272
# -----------------------
# number of flights for keyFlight = ‘1’ :  345
# number of flights for keyFlight = ‘2’ :  374
# number of flights for keyFlight = ‘3’ :  370
# -----------------------
# number of flights for keyFlight = ‘1’ :  262
# number of flights for keyFlight = ‘2’ :  308
# number of flights for keyFlight = ‘3’ :  271
# -----------------------
# number of flights for keyFlight = ‘1’ :  385
# number of flights for keyFlight = ‘2’ :  377
# number of flights for keyFlight = ‘3’ :  398
# -----------------------
# number of flights for keyFlight = ‘1’ :  247
# number of flights for keyFlight = ‘2’ :  233
# number of flights for keyFlight = ‘3’ :  275
# -----------------------
# number of flights for keyFlight = ‘1’ :  382
# number of flights for keyFlight = ‘2’ :  366
# number of flights for keyFlight = ‘3’ :  372
# -----------------------
# number of flights for keyFlight = ‘1’ :  308
# number of flights for keyFlight = ‘2’ :  275
# number of flights for keyFlight = ‘3’ :  257
# -----------------------
# number of flights for keyFlight = ‘1’ :  367
# number of flights for keyFlight = ‘2’ :  388
# number of flights for keyFlight = ‘3’ :  359
# -----------------------
# number of flights for keyFlight = ‘1’ :  386
# number of flights for keyFlight = ‘2’ :  285
# number of flights for keyFlight = ‘3’ :  253
# -----------------------
# number of flights for keyFlight = ‘1’ :  284
# number of flights for keyFlight = ‘2’ :  411
# number of flights for keyFlight = ‘3’ :  376
# -----------------------
# number of flights for keyFlight = ‘1’ :  390
# number of flights for keyFlight = ‘2’ :  282
# number of flights for keyFlight = ‘3’ :  271
# -----------------------
# number of flights for keyFlight = ‘1’ :  286
# number of flights for keyFlight = ‘2’ :  385
# number of flights for keyFlight = ‘3’ :  357
# -----------------------
# number of flights for keyFlight = ‘1’ :  406
# number of flights for keyFlight = ‘2’ :  356
# number of flights for keyFlight = ‘3’ :  277
# -----------------------
# number of flights for keyFlight = ‘1’ :  304
# number of flights for keyFlight = ‘2’ :  271
# number of flights for keyFlight = ‘3’ :  372
# -----------------------
# number of flights for keyFlight = ‘1’ :  371
# number of flights for keyFlight = ‘2’ :  380
# number of flights for keyFlight = ‘3’ :  289
# -----------------------
# number of flights for keyFlight = ‘1’ :  268
# number of flights for keyFlight = ‘2’ :  286
# number of flights for keyFlight = ‘3’ :  347
# -----------------------
# number of flights for keyFlight = ‘1’ :  397
# number of flights for keyFlight = ‘2’ :  415
# number of flights for keyFlight = ‘3’ :  247
# -----------------------
# number of flights for keyFlight = ‘1’ :  258
# number of flights for keyFlight = ‘2’ :  278
# number of flights for keyFlight = ‘3’ :  396
# -----------------------
# number of flights for keyFlight = ‘1’ :  349
# number of flights for keyFlight = ‘2’ :  398
# number of flights for keyFlight = ‘3’ :  288
# -----------------------
# number of flights for keyFlight = ‘1’ :  262
# number of flights for keyFlight = ‘2’ :  267
# number of flights for keyFlight = ‘3’ :  377
# -----------------------
# number of flights for keyFlight = ‘1’ :  344
# number of flights for keyFlight = ‘2’ :  367
# number of flights for keyFlight = ‘3’ :  280
# -----------------------
# number of flights for keyFlight = ‘1’ :  257
# number of flights for keyFlight = ‘2’ :  281
# number of flights for keyFlight = ‘3’ :  333
# -----------------------
# number of flights for keyFlight = ‘1’ :  379
# number of flights for keyFlight = ‘2’ :  367
# number of flights for keyFlight = ‘3’ :  261
# -----------------------
# number of flights for keyFlight = ‘1’ :  292
# number of flights for keyFlight = ‘2’ :  301
# number of flights for keyFlight = ‘3’ :  375
# -----------------------
# number of flights for keyFlight = ‘1’ :  338
# number of flights for keyFlight = ‘2’ :  365
# number of flights for keyFlight = ‘3’ :  299
# -----------------------
# number of flights for keyFlight = ‘1’ :  292
# number of flights for keyFlight = ‘2’ :  260
# number of flights for keyFlight = ‘3’ :  339
# -----------------------
